# %% [markdown]
# ## Importações

# %%
import mofdb_client
import requests
import pandas as pd
from funcoes import *
import pickle

# %%
r = requests.get("https://mof.tech.northwestern.edu/mofs.json")

print(r)
# Out:
# <Response [200]>

# %%
data_json = r.json()['results']

# %%
df_json = pd.DataFrame.from_dict(data_json)

# %% [markdown]
# ## Tratamento de dados

# %%
df_json = funcao_extrair_features_isotherms(df_json)

# %%
df_cif = df_json.iloc[:]
df_cif = extrair_cif(df_cif,minimo=3)
# Out:
# c:\venv\ilumpy\lib\site-packages\pymatgen\io\cif.py:1134: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# ...
# ElementProperty:   0%|          | 0/200 [00:00<?, ?it/s]

# %%
df_json = df_json.drop(labels='cif', axis=1)

# %%
df_data = pd.concat([df_json,df_cif],axis=1)
display(df_data)
# Out:
#         id    lcd    pld               url      name  pxrd  \
# 0    15338  10.75   9.75  /mofs/15338.json    hMOF-6  None
# 1    15339  11.75  10.75  /mofs/15339.json    hMOF-0  None
# 2    15340   4.25   2.25  /mofs/15340.json    hMOF-7  None
# 3    15341   3.25   2.75  /mofs/15341.json    hMOF-5  None
# 4    15342  10.75   9.25  /mofs/15342.json    hMOF-3  None
# ..     ...    ...    ...               ...       ...   ...
# 195  15533  10.75   9.25  /mofs/15533.json  hMOF-197  None
# 196  15534   8.25   7.25  /mofs/15534.json  hMOF-195  None
# 197  15535   5.25   2.75  /mofs/15535.json  hMOF-198  None
# 198  15536   7.75   4.25  /mofs/15536.json  hMOF-196  None
# 199  15537  11.25   9.75  /mofs/15537.json  hMOF-199  None
#
#                                                  heats  \
# 0    [{'id': 6452473, 'DOI': '10.1039/C2EE23201D', ...
# 1    [{'id': 6452467, 'DOI': '10.1039/C2EE23201D', ...
# 2    [{'id': 6452474, 'DOI': '10.1039/C2EE23201D', ...
# ...

# %%
print(df_data['pore_size_distribution']) #???
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 195    None
# 196    None
# 197    None
# 198    None
# 199    None
# Name: pore_size_distribution, Length: 200, dtype: object

# %%
df_data.to_excel('df_data_xlsx.xlsx',index=False)

# %%
with open('dataframe.pkl', 'wb') as f:
    pickle.dump(df_data, f)
